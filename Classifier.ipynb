# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC

import pandas as pd
import numpy, string
import matplotlib
import scipy

# %% [markdown]
# ## Load Data ##

# %%
df = pd.read_csv("MOCK_DATA.csv")
df.head()
# Out:
#    id first_name last_name                      email  gender      ip_address  \
# 0   1    Cornell       Nye    cnye0@sciencedirect.com    Male  171.95.103.238
# 1   2     Joseph  Deverill  jdeverill1@whitehouse.gov    Male  173.130.94.151
# 2   3     Pegeen    Lerego      plerego2@amazon.co.jp  Female    108.48.103.4
# 3   4     Janith    Panons      jpanons3@berkeley.edu  Female     34.27.99.66
# 4   5    Cissiee    Myhill     cmyhill4@newyorker.com  Female  28.172.195.129
#
#           phone              address          ssn
# 0  128-612-4011    86 Mcbride Street  608-45-8721
# 1  278-837-7782  6620 Clarendon Road  409-65-3396
# 2  353-423-4599   5711 Troy Junction  204-67-8040
# 3  535-128-9172      32 Manley Alley  396-47-0769
# 4  717-836-1731  750 Corben Junction  691-91-8581

# %% [markdown]
# Transpose the data so that we can classify each column from original dataset. Also, add a value that contains the category of data that the row contains.

# %%
df = df.transpose()
df['category'] = df.index
df = df.drop('id')
df.head(10)
# Out:
#                                   0                          1  \
# first_name                  Cornell                     Joseph
# last_name                       Nye                   Deverill
# email       cnye0@sciencedirect.com  jdeverill1@whitehouse.gov
# gender                         Male                       Male
# ip_address           171.95.103.238             173.130.94.151
# phone                  128-612-4011               278-837-7782
# address           86 Mcbride Street        6620 Clarendon Road
# ssn                     608-45-8721                409-65-3396
#
#                                 2                      3  \
# first_name                 Pegeen                 Janith
# last_name                  Lerego                 Panons
# email       plerego2@amazon.co.jp  jpanons3@berkeley.edu
# gender                     Female                 Female
# ip_address           108.48.103.4            34.27.99.66
# phone                353-423-4599           535-128-9172
# address        5711 Troy Junction        32 Manley Alley
# ssn                   204-67-8040            396-47-0769
#
#                                  4                        5  \
# first_name                 Cissiee                    Berty
# last_name                   Myhill              Itzkovwitch
# email       cmyhill4@newyorker.com  bitzkovwitch5@globo.com
# gender                      Female                     Male
# ip_address          28.172.195.129             187.4.247.67
# phone                 717-836-1731             232-641-2554
# address        750 Corben Junction       94120 Ilene Avenue
# ssn                    691-91-8581              362-44-7446
#
#                                6                           7  \
# first_name                Thelma                        Roze
# last_name                  Kynnd                    Lanktree
# email       tkynnd6@omniture.com  rlanktree7@theatlantic.com
# gender                    Female                      Female
# ip_address          69.161.64.47               23.124.48.207
# phone               961-528-1763                404-540-3686
# address        6553 Farwell Pass           8 Lerdahl Terrace
# ssn                  223-43-4071                 274-21-5681
#
#                                         8                    9     ...      \
# first_name                        Laurena                 Tris     ...
# last_name                         Wakeman               Blaske     ...
# email       lwakeman8@businessinsider.com  tblaske9@dion.ne.jp     ...
# gender                             Female                 Male     ...
# ip_address                  242.19.17.111        237.41.32.171     ...
# phone                        900-866-9467         582-157-5830     ...
# address                  07324 Texas Pass     8 Rigney Parkway     ...
# ssn                           863-58-5434          775-29-5872     ...
#
#                                 1991                    1992  \
# first_name                    Rhetta                   Quill
# last_name                 Shrimptone                  Cruwys
# email       rshrimptonerj@sphinn.com  qcruwysrk@illinois.edu
# gender                        Female                    Male
# ip_address            182.251.90.108           11.213.152.71
# phone                   559-992-7552            921-201-0213
# address             5913 Elmside Way      6413 Coleman Trail
# ssn                      557-91-1165             274-80-0533
#
#                              1993                  1994                 1995  \
# first_name                 Mignon                 Denna                 Dasi
# last_name                Brampton              Tussaine                Frean
# email       mbramptonrl@phpbb.com  dtussainerm@etsy.com   dfreanrn@topsy.com
# gender                     Female                Female               Female
# ip_address        250.197.218.243       157.171.135.231      110.140.197.129
# phone                639-710-4689          296-586-9865         827-635-7555
# address             9 Utah Center     2 Kenwood Terrace  156 Evergreen Trail
# ssn                   569-86-1591           465-29-4146          197-67-3905
#
#                                 1996                  1997  \
# first_name                     Lance                  Jody
# last_name                Zienkiewicz                O'Hone
# email       lzienkiewiczro@phpbb.com  johonerp@squidoo.com
# gender                          Male                Female
# ip_address             137.211.56.40         165.103.7.160
# phone                   901-524-0024          889-755-8886
# address              50 North Center  35 Kingsford Terrace
# ssn                      389-52-6103           612-74-6131
#
#                                1998                 1999    category
# first_name                      Ron            Benedicto  first_name
# last_name                    Divall             Partener   last_name
# email       rdivallrq@webeden.co.uk  bpartenerrr@last.fm       email
# gender                         Male                 Male      gender
# ip_address           235.121.72.181        168.40.62.253  ip_address
# phone                  299-231-7780         556-471-2895       phone
# address        84073 Carberry Alley    3 Holy Cross Hill     address
# ssn                     162-84-8141          245-65-2069         ssn
#
# [8 rows x 2001 columns]

# %% [markdown]
# Transform dataframe so that each row is ('category', 'value')

# %%
df = df.melt(id_vars=['category'])
df.head(10)
# Out:
#      category variable                    value
# 0  first_name        0                  Cornell
# 1   last_name        0                      Nye
# 2       email        0  cnye0@sciencedirect.com
# 3      gender        0                     Male
# 4  ip_address        0           171.95.103.238
# 5       phone        0             128-612-4011
# 6     address        0        86 Mcbride Street
# 7         ssn        0              608-45-8721
# 8  first_name        1                   Joseph
# 9   last_name        1                 Deverill

# %% [markdown]
# Extract X, Y from dataframe and create a train/test split. Note that since X contains strings, we need to vectorize them. To do this, I used sklearn's HashingVectorizer. Then the train/test split is made using the transformed X(value) and the original Y(category) from the dataframe.

# %%
hash_vect = HashingVectorizer()
X = hash_vect.fit_transform(df['value'])
y = df['category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %% [markdown]
# Now we create the LinearSVC model and fit the data to the model.

# %%
clf = LinearSVC()
clf.fit(X_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
clf.score(X_test, y_test)
# Out:
# 0.8558712121212121
